# %%
import pandas as pd
import glob
import os

df_sucio = []

# Buscamos todos los .csv dentro de cualquier subcarpeta de scraps
archivos = glob.glob("scraps/**/*.csv", recursive=True)

if archivos:
    # Ordenamos por fecha de modificación para obtener el más reciente
    ultimo_archivo = max(archivos, key=os.path.getmtime)
    
    print(f"Cargando el archivo más reciente: {ultimo_archivo}")
    df_sucio = pd.read_csv(ultimo_archivo)
    
    # Imprimimos el head
    print("-" * 30)
    print(df_sucio.dtypes)
else:
    print("No se encontró ningún archivo CSV en la carpeta 'scraps'.")
# Out:
# Cargando el archivo más reciente: scraps/15-02-2026/ofertas_it_16-34.csv
# ------------------------------
# id                        object
# site                      object
# job_url                   object
# job_url_direct            object
# title                     object
# company                   object
# location                  object
# date_posted               object
# job_type                  object
# salary_source            float64
# interval                 float64
# min_amount               float64
# max_amount               float64
# currency                 float64
# is_remote                   bool
# job_level                 object
# job_function              object
# listing_type             float64
# emails                    object
# description               object
# company_industry          object
# company_url               object
# company_logo              object
# company_url_direct       float64
# company_addresses        float64
# ...

# %%
df_clean = df_sucio.copy()

# %%
df_clean.drop(columns=['site','job_url','company_url','company_logo'], inplace=True)

# %%
mapeoTipos = {
    'id' : 'string',
    'title' : 'string',
    'company' : 'string',
    'location' : 'string',
    'job_type' : 'string',
    'job_level' : 'string',
    'job_function' : 'string',
    'description' : 'string',
    'company_industry' : 'string',
    'search_location' : 'string'
    }

df_clean = df_clean.astype(mapeoTipos)

# %%
df_clean['job_url_direct'] = df_clean['job_url_direct'].notna()

df_clean['date_posted'] = pd.to_datetime(df_clean['date_posted'], errors='coerce')

df_clean['emails'] = df_clean['emails'].notna()

# %%
columnas_finales = df_clean.columns.tolist()

for columna in [col for col in columnas_finales if col not in ['description','id']]:
    print(f"Columna: {columna}")
    print(f"Valores únicos: {df_clean[columna].value_counts()}")
# Out:
# Columna: job_url_direct
# Valores únicos: job_url_direct
# False    108
# True      32
# Name: count, dtype: int64
# Columna: title
# Valores únicos: title
# Data Engineer                                    15
# Graduate software engineer                        6
# Data Analysis Internship                          3
# Senior Data Engineer                              3
# Data Engineer - EY GDS Spain - Hybrid             2
#                                                  ..
# Software Engineer, Platform - Malaga, Spain       1
# Juju Software Engineer (Go)                       1
# Data Analytics Engineer Banca                     1
# Software Engineer - Python - Container Images     1
# Senior Data Engineer - Databricks (m/f/*)         1
# Name: count, Length: 107, dtype: Int64
# Columna: company
# Valores únicos: company
# Canonical                    28
# Bending Spoons                6
# EPAM Systems                  5
# Deutsche Telekom              4
# ...
